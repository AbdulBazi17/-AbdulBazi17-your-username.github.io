# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulBazi17/-AbdulBazi17-your-username.github.io/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create index.html
html_content = """
"""
with open("index.html", "w") as f:
    f.write(html_content)

# Create style.css
css_content = """
"""
with open("style.css", "w") as f:
    f.write(css_content)

print("Files created successfully!")
# Out:
# Files created successfully!

# %%
# %%html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Abdul Bashith B | Portfolio</title>
#     <link rel="stylesheet" href="style.css">
#     <script src="https://kit.fontawesome.com/your-fontawesome-key.js" crossorigin="anonymous"></script>
# </head>
# <body>
#     <nav>
#         <div class="logo">BASHITH<span>.</span></div>
#         <ul>
#             <li><a href="#about">About</a></li>
#             <li><a href="#skills">Skills</a></li>
#             <li><a href="#projects">Projects</a></li>
#             <li><a href="mailto:bashithabdul41@gmail.com" class="btn">Contact</a></li>
#         </ul>
#     </nav>
#
#     <header class="hero">
#         <div class="hero-content">
#             <h1>Hi, I'm <span>Abdul Bashith B</span></h1>
#             <p>Data Science Graduate & Analytics Specialist</p>
#             <div class="hero-btns">
#                 <a href="#projects" class="btn-primary">View Projects</a>
#                 <a href="https://www.linkedin.com/in/abdul-bashith-709705289" target="_blank" class="btn-secondary">LinkedIn</a>
#             </div>
#         </div>
#     </header>
#
#     <section id="about" class="section">
#         <h2>Career Objective</h2>
#         <p>Motivated and detail-oriented individual with expertise in Excel, SQL, and Python. Skilled in automating workflows and delivering actionable insights through visual storytelling. </p>
#     </section>
#
#     <section id="skills" class="section gray-bg">
#         <h2>Technical Toolkit</h2>
#         <div class="skills-grid">
#             <div class="skill-card">Python</div>
#             <div class="skill-card">SQL</div>
#             <div class="skill-card">Power BI</div>
#             <div class="skill-card">Tableau</div>
#             <div class="skill-card">Excel</div>
#         </div>
#     </section>
#
#     <section id="projects" class="section">
#         <h2>Featured Projects</h2>
#         <div class="project-container">
#             <div class="project-card">
#                 <h3>Car Sales EDA (Python)</h3>
#                 <p>Identified top-performing salespersons based on commission and volume. </p>
#             </div>
#             <div class="project-card">
#                 <h3>IMDB Data Analysis</h3>
#                 <p>Advanced SQL project analyzing movie production trends and genre popularity. </p>
#             </div>
#             <div class="project-card">
#                 <h3>Student Enrollment Dashboard</h3>
#                 <p>Power BI visualization of student enrollment and fee data. </p>
#             </div>
#         </div>
#     </section>
#
#     <footer>
#         <p>© 2025 Abdul Bashith B | Pollachi, Tamil Nadu</p>
#     </footer>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Abdul Bashith B | Portfolio</title>
#     <link rel="stylesheet" href="style.css">
#     <script src="https://kit.fontawesome.com/your-fontawesome-key.js" crossorigin="anonymous"></script>
# </head>
# <body>
#     <nav>
#         <div class="logo">BASHITH<span>.</span></div>
#         <ul>
#             <li><a href="#about">About</a></li>
#             <li><a href="#skills">Skills</a></li>
#             <li><a href="#projects">Projects</a></li>
#             <li><a href="mailto:bashithabdul41@gmail.com" class="btn">Contact</a></li>
#         </ul>
#     </nav>
#
#     <header class="hero">
#         <div class="hero-content">
#             <h1>Hi, I'm <span>Abdul Bashith B</span></h1>
#             <p>Data Science Graduate & Analytics Specialist</p>
#             <div class="hero-btns">
# ...

# %%
# %%writefile style.css
# :root {
#     --bg-color: #0f172a;
#     --card-bg: #1e293b;
#     --accent: #38bdf8;
#     --text-main: #f8fafc;
#     --text-dim: #94a3b8;
# }
#
# * { margin: 0; padding: 0; box-sizing: border-box; font-family: 'Inter', sans-serif; }
#
# body { background-color: var(--bg-color); color: var(--text-main); line-height: 1.6; }
#
# nav { display: flex; justify-content: space-between; align-items: center; padding: 2rem 10%; position: sticky; top: 0; background: rgba(15, 23, 42, 0.9); backdrop-filter: blur(10px); }
#
# .logo { font-size: 1.5rem; font-weight: 800; }
# .logo span { color: var(--accent); }
#
# nav ul { display: flex; list-style: none; gap: 2rem; }
# nav ul li a { text-decoration: none; color: var(--text-main); font-weight: 500; }
#
# .hero { height: 80vh; display: flex; align-items: center; justify-content: center; text-align: center; }
# .hero h1 span { color: var(--accent); }
# .hero p { color: var(--text-dim); font-size: 1.2rem; margin: 1rem 0; }
#
# .section { padding: 5rem 10%; }
# .section h2 { font-size: 2rem; margin-bottom: 2rem; border-left: 4px solid var(--accent); padding-left: 1rem; }
#
# .skills-grid { display: grid; grid-template-columns: repeat(auto-fit, minmax(120px, 1fr)); gap: 1rem; }
# .skill-card { background: var(--card-bg); padding: 1.5rem; text-align: center; border-radius: 12px; border: 1px solid #334155; }
#
# .project-container { display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 2rem; }
# .project-card { background: var(--card-bg); padding: 2rem; border-radius: 16px; border: 1px solid #334155; transition: 0.3s; }
# .project-card:hover { border-color: var(--accent); transform: translateY(-5px); }
#
# .btn-primary { background: var(--accent); color: #000; padding: 0.8rem 2rem; border-radius: 8px; text-decoration: none; font-weight: bold; }
# Out:
# Overwriting style.css

# %%
# Configure your identity
# !git config --global user.email "bashithabdul41@gmail.com"
# !git config --global user.name "Abdul Bashith B"

# Initialize the repository locally in Colab
# !git init
# !git add .
# !git commit -m "https://github.com/AbdulBazi17/-AbdulBazi17-your-username.github.io.git"

# Replace <TOKEN> with your GitHub Personal Access Token
# and <USERNAME> with your GitHub username
# !git remote add origin "https://github.com/AbdulBazi17/-AbdulBazi17-your-username.github.io"
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# On branch main
# nothing to commit, working tree clean
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
